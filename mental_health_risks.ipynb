# %% [markdown]
# Mental Health Risks Data Set exploration

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('mhrds.csv')
print(df.shape)

df.head()
# Out:
# (25000, 25)
#    age  gender marital_status education_level employment_status  sleep_hours  \
# 0   56   Other         Single        Bachelor        Unemployed          8.6
# 1   47    Male         Single        Bachelor        Unemployed          4.5
# 2   56  Female       Divorced        Bachelor           Student          3.1
# 3   59   Other        Married        Bachelor          Employed          7.0
# 4   58    Male         Single     High School     Self-Employed          5.1
#
#    physical_activity_hours_per_week  screen_time_hours_per_day  \
# 0                               2.8                        9.6
# 1                               2.7                        3.0
# 2                              14.1                        7.2
# 3                               0.5                       10.3
# 4                               2.5                        1.2
#
#    social_support_score  work_stress_level  ...  depression_score  \
# ...

# %%
print(df.columns)
df.info()
# Out:
# Index(['age', 'gender', 'marital_status', 'education_level',
#        'employment_status', 'sleep_hours', 'physical_activity_hours_per_week',
#        'screen_time_hours_per_day', 'social_support_score',
#        'work_stress_level', 'academic_pressure_level',
#        'job_satisfaction_score', 'financial_stress_level',
#        'working_hours_per_week', 'anxiety_score', 'depression_score',
#        'stress_level', 'mood_swings_frequency',
#        'concentration_difficulty_level', 'panic_attack_history',
#        'family_history_mental_illness', 'previous_mental_health_diagnosis',
#        'therapy_history', 'substance_use', 'mental_health_risk'],
#       dtype='str')
# <class 'pandas.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 25 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   age                               25000 non-null  int64
# ...

# %%
df.isnull().sum()
# Out:
# age                                 0
# gender                              0
# marital_status                      0
# education_level                     0
# employment_status                   0
# sleep_hours                         0
# physical_activity_hours_per_week    0
# screen_time_hours_per_day           0
# social_support_score                0
# work_stress_level                   0
# academic_pressure_level             0
# job_satisfaction_score              0
# financial_stress_level              0
# working_hours_per_week              0
# anxiety_score                       0
# depression_score                    0
# stress_level                        0
# mood_swings_frequency               0
# concentration_difficulty_level      0
# panic_attack_history                0
# family_history_mental_illness       0
# previous_mental_health_diagnosis    0
# therapy_history                     0
# substance_use                       0
# mental_health_risk                  0
# ...

# %%
df.describe()
# Out:
#                 age   sleep_hours  physical_activity_hours_per_week  \
# count  25000.000000  25000.000000                      25000.000000
# mean      39.072560      6.509516                          7.515400
# std       12.404948      2.015586                          4.324346
# min       18.000000      3.000000                          0.000000
# 25%       28.000000      4.800000                          3.800000
# 50%       39.000000      6.500000                          7.500000
# 75%       50.000000      8.200000                         11.300000
# max       60.000000     10.000000                         15.000000
#
#        screen_time_hours_per_day  social_support_score  work_stress_level  \
# count               25000.000000           25000.00000       25000.000000
# mean                    6.469132               5.50840           5.517080
# std                     3.167682               2.88694           2.864548
# ...

# %%
print(df.dtypes)
# Out:
# age                                   int64
# gender                                  str
# marital_status                          str
# education_level                         str
# employment_status                       str
# sleep_hours                         float64
# physical_activity_hours_per_week    float64
# screen_time_hours_per_day           float64
# social_support_score                  int64
# work_stress_level                     int64
# academic_pressure_level               int64
# job_satisfaction_score                int64
# financial_stress_level                int64
# working_hours_per_week                int64
# anxiety_score                         int64
# depression_score                      int64
# stress_level                          int64
# mood_swings_frequency                 int64
# concentration_difficulty_level        int64
# panic_attack_history                  int64
# family_history_mental_illness         int64
# ...

# %%
df.isna()
df.isnull().sum()
# Out:
# age                                 0
# gender                              0
# marital_status                      0
# education_level                     0
# employment_status                   0
# sleep_hours                         0
# physical_activity_hours_per_week    0
# screen_time_hours_per_day           0
# social_support_score                0
# work_stress_level                   0
# academic_pressure_level             0
# job_satisfaction_score              0
# financial_stress_level              0
# working_hours_per_week              0
# anxiety_score                       0
# depression_score                    0
# stress_level                        0
# mood_swings_frequency               0
# concentration_difficulty_level      0
# panic_attack_history                0
# family_history_mental_illness       0
# previous_mental_health_diagnosis    0
# therapy_history                     0
# substance_use                       0
# mental_health_risk                  0
# ...

# %%
df.loc[df['gender'].isna()]
# Out:
# Empty DataFrame
# Columns: [age, gender, marital_status, education_level, employment_status, sleep_hours, physical_activity_hours_per_week, screen_time_hours_per_day, social_support_score, work_stress_level, academic_pressure_level, job_satisfaction_score, financial_stress_level, working_hours_per_week, anxiety_score, depression_score, stress_level, mood_swings_frequency, concentration_difficulty_level, panic_attack_history, family_history_mental_illness, previous_mental_health_diagnosis, therapy_history, substance_use, mental_health_risk]
# Index: []
#
# [0 rows x 25 columns]

# %%
df.duplicated(keep=False).sum()
# Out:
# np.int64(0)

# %%
df['social_support_score'].value_counts()
# Out:
# social_support_score
# 10    2605
# 2     2546
# 4     2521
# 9     2508
# 6     2498
# 3     2490
# 1     2486
# 8     2472
# 5     2463
# 7     2411
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#                 age   sleep_hours  physical_activity_hours_per_week  \
# count  25000.000000  25000.000000                      25000.000000
# mean      39.072560      6.509516                          7.515400
# std       12.404948      2.015586                          4.324346
# min       18.000000      3.000000                          0.000000
# 25%       28.000000      4.800000                          3.800000
# 50%       39.000000      6.500000                          7.500000
# 75%       50.000000      8.200000                         11.300000
# max       60.000000     10.000000                         15.000000
#
#        screen_time_hours_per_day  social_support_score  work_stress_level  \
# count               25000.000000           25000.00000       25000.000000
# mean                    6.469132               5.50840           5.517080
# std                     3.167682               2.88694           2.864548
# ...

# %%
df['sleep_hours'].hist(bins=10)
# Out:
# <Axes: >

# %%
sns.boxplot(x=df['sleep_hours'])
# Out:
# <Axes: xlabel='sleep_hours'>

# %%
df.columns
df_corr = df[['age', 'sleep_hours', 'physical_activity_hours_per_week',
       'screen_time_hours_per_day', 'social_support_score',
       'work_stress_level', 'academic_pressure_level',
       'job_satisfaction_score', 'financial_stress_level',
       'working_hours_per_week', 'anxiety_score', 'depression_score',
       'stress_level', 'mood_swings_frequency',
       'concentration_difficulty_level', 'panic_attack_history',
       'family_history_mental_illness', 'previous_mental_health_diagnosis',
       'therapy_history', 'substance_use', 'mental_health_risk']].corr()
df_corr
# Out:
#                                        age  sleep_hours  \
# age                               1.000000    -0.000574
# sleep_hours                      -0.000574     1.000000
# physical_activity_hours_per_week -0.002980     0.010025
# screen_time_hours_per_day         0.000598     0.003649
# social_support_score             -0.001980    -0.000007
# work_stress_level                 0.003582    -0.001864
# academic_pressure_level          -0.003922     0.001212
# job_satisfaction_score           -0.001850    -0.006950
# financial_stress_level           -0.003091     0.005834
# working_hours_per_week           -0.006816    -0.002254
# anxiety_score                    -0.013231    -0.007506
# depression_score                  0.001717     0.007773
# stress_level                      0.009125     0.004413
# mood_swings_frequency             0.000835    -0.005756
# concentration_difficulty_level   -0.021252     0.001992
# panic_attack_history              0.002657    -0.007146
# ...

# %%
fig, ax = plt.subplots(figsize=(21,21))

sns.heatmap(df_corr, annot=True, cmap='mako')
# Out:
# <Axes: >

# %%
df.columns
df['mental_health_risk'].describe()
# Out:
# count    25000.000000
# mean         0.778520
# std          0.691409
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          1.000000
# max          2.000000
# Name: mental_health_risk, dtype: float64

# %%
sns.pairplot(df[['age', 'mental_health_risk']], height=5, aspect = 1.5, diag_kind='kde')
